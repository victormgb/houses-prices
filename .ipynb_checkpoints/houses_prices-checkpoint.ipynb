# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train['type_dt']= 'train'
test['type_dt'] = 'test'
full = pd.concat([train, test])

# %%
full.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2008
# 1         Lvl    AllPub  ...    NaN   NaN         NaN       0      5   2007
# 2         Lvl    AllPub  ...    NaN   NaN         NaN       0      9   2008
# 3         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2006
# 4         Lvl    AllPub  ...    NaN   NaN         NaN       0     12   2008
#
#   SaleType  SaleCondition  SalePrice  type_dt
# 0       WD         Normal   208500.0    train
# 1       WD         Normal   181500.0    train
# 2       WD         Normal   223500.0    train
# 3       WD        Abnorml   140000.0    train
# 4       WD         Normal   250000.0    train
#
# [5 rows x 82 columns]

# %%
full.shape
# Out:
# (2919, 82)

# %%
plt.hist(train['SalePrice'])
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Check null values

# %%
null_values = full.isnull().sum().sort_values(ascending=False)

# %%
check_nulls_keys = []
for key,value in null_values.items():
    percent_null = (100*value)/len(full)
    if(percent_null > 30):
        check_nulls_keys.append(key)

# %%
check_nulls_keys = check_nulls_keys[:4]
check_nulls_keys
# Out:
# ['PoolQC', 'MiscFeature', 'Alley', 'Fence']

# %%
full = full.drop(columns=check_nulls_keys)

# %%
full.shape
# Out:
# (2919, 78)

# %% [markdown]
# # EDA In categorical Columns

# %%
categorical_columns = ['MSZoning','Electrical','KitchenQual','RoofStyle','Neighborhood','BsmtQual','ExterQual','BsmtExposure','HouseStyle','GarageFinish','BsmtFinType1','GarageType']

# %%
for x in range(len(categorical_columns)):
    sns.boxplot(data=train,x=categorical_columns[x],y='SalePrice')
    plt.title(categorical_columns[x])
    plt.show()

# %%
for x in range(len(categorical_columns)):
    plt.hist(train[~train[categorical_columns[x]].isnull()][categorical_columns[x]])
    plt.title(categorical_columns[x])
    plt.show()

# %% [markdown]
# ## Cleaning Data and selecting numerical features

# %%
full.drop('Id', axis=1, inplace=True)
full.drop('MoSold',axis=1, inplace= True)
full.drop('YrSold',axis=1, inplace= True)

train.drop('Id', axis=1, inplace=True)
train.drop('MoSold',axis=1, inplace= True)
train.drop('YrSold',axis=1, inplace= True)

# %%
num_cols = ['LotFrontage', 'OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF','GrLivArea', 'GarageYrBlt', 'GarageArea', 'GarageCars', 'TotRmsAbvGrd']

# %%
df_num = train[num_cols]

# %%
num_cols
# Out:
# ['LotFrontage',
#  'OverallQual',
#  'YearBuilt',
#  'YearRemodAdd',
#  'TotalBsmtSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'GarageCars',
#  'TotRmsAbvGrd']

# %% [markdown]
# # EDA In numerical Columns

# %%
for x in range(len(num_cols)):
    sns.boxplot(data=train, x=num_cols[x], y='SalePrice')
    plt.title(num_cols[x])
    plt.show()

# %%
for x in range(len(num_cols)):
    plt.hist(train[num_cols[x]])
    plt.title(num_cols[x])
    plt.show()

# %%
plt.subplots(figsize=(20,15))
corr_matrix_features = num_cols
corr_matrix_features.append('SalePrice')
corr_matrix = train[corr_matrix_features].corr()
sns.heatmap(corr_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Dealing with null values in categorical features

# %%
df_train_categorical = full[categorical_columns]
df_train_categorical = df_train_categorical.reset_index()
df_train_categorical.drop(columns=['index'],axis=1,inplace= True)

# %%
df_train_categorical.shape
# Out:
# (2919, 12)

# %% [markdown]
# ## After clean the data assign the target

# %%
y = full[full['type_dt'] == 'train']['SalePrice']

# %% [markdown]
# # Dealing with null values in numerical features

# %%
df_train_num = full[num_cols]

# %%
df_train_num.shape
# Out:
# (2919, 10)

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy="median")
imputer.fit(df_train_num)
df_train_num = pd.DataFrame(imputer.transform(df_train_num), columns=num_cols)

df_train_num.shape
# Out:
# (2919, 10)

# %%
df_train_num.head()
# Out:
#    LotFrontage  OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  GrLivArea  \
# 0         65.0          7.0     2003.0        2003.0        856.0     1710.0
# 1         80.0          6.0     1976.0        1976.0       1262.0     1262.0
# 2         68.0          7.0     2001.0        2002.0        920.0     1786.0
# 3         60.0          7.0     1915.0        1970.0        756.0     1717.0
# 4         84.0          8.0     2000.0        2000.0       1145.0     2198.0
#
#    GarageYrBlt  GarageArea  GarageCars  TotRmsAbvGrd
# 0       2003.0       548.0         2.0           8.0
# 1       1976.0       460.0         2.0           6.0
# 2       2001.0       608.0         2.0           6.0
# 3       1998.0       642.0         3.0           7.0
# 4       2000.0       836.0         3.0           9.0

# %%
df_train_categorical
# Out:
#      MSZoning Electrical KitchenQual RoofStyle Neighborhood BsmtQual  \
# 0          RL      SBrkr          Gd     Gable      CollgCr       Gd
# 1          RL      SBrkr          TA     Gable      Veenker       Gd
# 2          RL      SBrkr          Gd     Gable      CollgCr       Gd
# 3          RL      SBrkr          Gd     Gable      Crawfor       TA
# 4          RL      SBrkr          Gd     Gable      NoRidge       Gd
# ...       ...        ...         ...       ...          ...      ...
# 2914       RM      SBrkr          TA     Gable      MeadowV       TA
# 2915       RM      SBrkr          TA     Gable      MeadowV       TA
# 2916       RL      SBrkr          TA     Gable      Mitchel       TA
# 2917       RL      SBrkr          TA     Gable      Mitchel       Gd
# 2918       RL      SBrkr          TA     Gable      Mitchel       Gd
#
#      ExterQual BsmtExposure HouseStyle GarageFinish BsmtFinType1 GarageType
# 0           Gd           No     2Story          RFn          GLQ     Attchd
# 1           TA           Gd     1Story          RFn          ALQ     Attchd
# 2           Gd           Mn     2Story          RFn          GLQ     Attchd
# 3           TA           No     2Story          Unf          ALQ     Detchd
# 4           Gd           Av     2Story          RFn          GLQ     Attchd
# ...        ...          ...        ...          ...          ...        ...
# 2914        TA           No     2Story          NaN          Unf        NaN
# 2915        TA           No     2Story          Unf          Rec    CarPort
# 2916        TA           No     1Story          Unf          ALQ     Detchd
# 2917        TA           Av     SFoyer          NaN          GLQ        NaN
# 2918        TA           Av     2Story          Fin          LwQ     Attchd
#
# [2919 rows x 12 columns]

# %%
df_train_num.isnull().sum().sort_values()
# Out:
# LotFrontage     0
# OverallQual     0
# YearBuilt       0
# YearRemodAdd    0
# TotalBsmtSF     0
# GrLivArea       0
# GarageYrBlt     0
# GarageArea      0
# GarageCars      0
# TotRmsAbvGrd    0
# dtype: int64

# %%
df_cleaned_2 = pd.concat([df_train_categorical, df_train_num, full['type_dt'].reset_index().drop(columns=['index'],axis=1)], axis=1)
df_cleaned_2.shape
# Out:
# (2919, 23)

# %%
df_cleaned_2.isnull().sum().sort_values(ascending=False)
# Out:
# GarageFinish    159
# GarageType      157
# BsmtExposure     82
# BsmtQual         81
# BsmtFinType1     79
# MSZoning          4
# KitchenQual       1
# Electrical        1
# ExterQual         0
# TotalBsmtSF       0
# TotRmsAbvGrd      0
# GarageCars        0
# GarageArea        0
# GarageYrBlt       0
# GrLivArea         0
# YearBuilt         0
# YearRemodAdd      0
# Neighborhood      0
# OverallQual       0
# LotFrontage       0
# RoofStyle         0
# HouseStyle        0
# type_dt           0
# dtype: int64

# %% [markdown]
# ## Aplying one hot encoding

# %%
df_cleaned = pd.get_dummies(df_cleaned_2,columns=categorical_columns)

# %%
df_cleaned = df_cleaned.fillna(df_cleaned.mean())

# %%
df_cleaned.isnull().sum().sort_values(ascending=False)
# Out:
# LotFrontage          0
# HouseStyle_1.5Fin    0
# BsmtExposure_Mn      0
# BsmtExposure_Gd      0
# BsmtExposure_Av      0
#                     ..
# RoofStyle_Hip        0
# RoofStyle_Gambrel    0
# RoofStyle_Gable      0
# RoofStyle_Flat       0
# GarageType_Detchd    0
# Length: 91, dtype: int64

# %% [markdown]
# # Dividing training set and test data set

# %%
X = df_cleaned.loc[df_cleaned['type_dt'] == 'train']
X_test = df_cleaned.loc[df_cleaned['type_dt'] == 'test']
X.drop(columns=['type_dt'],axis=1,inplace=True)
X_test.drop(columns=['type_dt'],axis=1,inplace=True)
# Out:
# /home/victormgb/anaconda3/envs/studyml/lib/python3.9/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
y = np.log1p(y)
plt.hist(y)
# Out:
# (array([  5.,  12.,  54., 184., 470., 400., 220.,  90.,  19.,   6.]),
#  array([10.46027076, 10.76769112, 11.07511148, 11.38253184, 11.6899522 ,
#         11.99737256, 12.30479292, 12.61221328, 12.91963363, 13.22705399,
#         13.53447435]),
#  <BarContainer object of 10 artists>)

# %%
df_cleaned.shape
# Out:
# (2919, 91)

# %% [markdown]
# # Select ML Algorithms to Use

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, LassoCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
estimators = {
   ' Linear': LinearRegression(),
    'Ridge': Ridge(alpha=0.5),
    'RandomForest': RandomForestRegressor(n_estimators = 10, random_state = 42),
    'GradientBoost': GradientBoostingRegressor(max_depth=8, min_samples_leaf=50, min_samples_split=500, n_estimators=360,random_state=10, subsample=0.8)
}

# %%
best_score = 0
best_model = ''
#y_test = np.expm1(y_test)
for key in estimators:
    results = cross_validate(estimators[key],X,y,scoring='r2',cv=5,n_jobs=1)
    mean_results_score = results['test_score'].mean()
    if(mean_results_score > best_score):
        best_score = mean_results_score
        best_model = key

# %%
best_model
# Out:
# 'GradientBoost'

# %%
selected_estimator = estimators[best_model]
selected_estimator.fit(X,y)
selected_estimator.predict(X_test)
# Out:
# array([11.62423329, 11.91791707, 12.08175231, ..., 11.9843046 ,
#        11.6667867 , 12.31453811])

# %%
y_pred = np.expm1(selected_estimator.predict(X_test))
y_test = pd.read_csv('./sample_submission.csv')['SalePrice']

# %%
from sklearn.metrics import mean_squared_error

rms_rf = mean_squared_error(y_test.to_numpy(), y_pred, squared=False)

# %%
rms_rf
# Out:
# 72083.36408389494

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (rms_rf / y_test)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)

print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 59.44 %.

# %%
submission = pd.DataFrame(pd.read_csv('./test.csv')['Id'])
submission['SalePrice'] = list(map(float, y_pred))

# %%
submission.to_csv('submission.csv', index=False)
